# %%
#Importing the necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#We will use the urllib.request module to open URLs. 
#We will use BeautifulSoup to extract data from html files. The Beautiful Soup library's name is bs4 which stands for BeautifulSoup, version 4.
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#After importing necessary modules, specify the URL containing the dataset and pass it to urlopen() to get the html of the page.
url = "https://www.hubertiming.com/results/2023WyEasterLong"
html = urlopen(url)

# %%
#After getting the HTML page create a Beautiful Soup object from the html. This is done by passing the html to the BeautifulSoup() function.
#The second argument 'lxml' is the html parser, one of several such parsers available for use.
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4

# %%
bs4.BeautifulSoup
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Race results for the 2023 Wy'Easter Skimo Race!</title>

# %%
# Print out the text
text = soup.get_text()
print(soup.text)
# Out:
# Race results for the 2023 Wy'Easter Skimo Race!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2023 Wy'easter Skimo Long - Open
#  Government Camp, Mt Hood, OR
#  March 26th, 2023
#
#
#
#  Snowgoat Skimo
#
#
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
#
#
#
#
#
# Huber Timing Home
#
#
#
#
#
# Long - Open:
#
#
# Finishers:
# 18
#
#
# Male:
# 11
#
#
# Female:
# 6
#
#
# Non-Binary:
# 1
#
#
#
#
#
#
#
#   Race Photos from Teresa Dalsager
#
#
#
#  Vertical - Open
#  Vertical - Heavy Mettle
#  Long - Open
#  Long - Heavy Mettle
#  Long - Splitmo
#  Recreation - Open
#  Summary
#
#
#
#
#
#
#
# Long - Open Results
#
#
#
# Search:
#
# Search
# Division:
#
# Men
# Women
# Non-Binary
# Masters Men
# Masters Women
# Masters Non-Binary
# F 25-29
# F 35-39
# F 40-44
# M 25-29
# M 30-34
# M 35-39
# M 40-44
# M 45-49
# M 55-59
# O 30-34
#  Filter
#
#
#
#
# Place
# Bib
# Name
# Gender
# Age
# City
# State
# Time
# Gender Place
# Age Group
# Age Group Place
#
#
#
#
# 1
# 345
#
#
#                     ZACH VIOLETT
#
#
# M
# 40
# BEND
# OR
# 1:33:19
#
#
#                     1 of 11
#
#
# M 40-44
#
#
#                     1 of 2
#
#
#
#
# 2
# 335
#
#
#                     KYLEE ROOD
#
#
# O
# 34
# BEND
# OR
# 1:42:56
#
#
#                     1 of 1
#
#
# O 30-34
#
#
#                     1 of 1
#
#
#
#
# 3
# 323
#
#
#                     ZEBEDIAH MILLSLAGL
#
#
# M
# 25
# BEND
# OR
# 1:52:07
#
#
#                     2 of 11
#
#
# M 25-29
#
#
#                     1 of 2
#
#
#
#
# 4
# 308
#
#
#                     DAVID GRIFFIN
#
#
# M
# 35
# SEATTLE
# WA
# 1:53:10
#
#
#                     3 of 11
#
#
# M 35-39
#
#
#                     1 of 2
#
#
#
#
# 5
# 326
#
#
#                     ADAM NILSEN
#
#
# M
# 30
# PORTLAND
# OR
# 1:54:57
#
#
#                     4 of 11
#
#
# M 30-34
#
#
#                     1 of 2
#
#
#
#
# 6
# 293
#
#
#                     KAITLIN ALLEN
#
#
# F
# 36
# BEND
# OR
# 1:56:01
#
#
#                     1 of 6
#
#
# F 35-39
#
#
#                     1 of 2
#
#
#
#
# 7
# 362
#
#
#                     GEORGE REYNYA
#
#
# M
# 47
# REDMOND
# WA
# 2:05:40
#
#
#                     5 of 11
#
#
# M 45-49
#
#
#                     1 of 2
#
#
#
#
# 8
# 305
#
#
#                     ELY GERBIN
#
#
# M
# 33
# ISSAQUAH
# WA
# 2:07:17
#
#
#                     6 of 11
#
#
# M 30-34
#
#
#                     2 of 2
#
#
#
#
# 9
# 509
#
#
#                     JOHN AMMONDSON
#
#
# M
# 29
# PORTLAND
# OR
# 2:08:22
#
#
#                     7 of 11
#
#
# M 25-29
#
#
#                     2 of 2
#
#
#
#
# 10
# 307
#
#
#                     TYLER GREEN
#
#
# M
# 39
# PORTLAND
# OR
# 2:09:02
#
#
#                     8 of 11
#
#
# M 35-39
#
#
#                     2 of 2
#
#
#
#
# 11
# 297
#
#
#                     MICHELLE BUNCKE
#
#
# F
# 27
# PORTLAND
# OR
# 2:10:01
#
#
#                     2 of 6
#
#
# F 25-29
#
#
#                     1 of 2
#
#
#
#
# 12
# 329
#
#
#                     DAN PACKMAN
#
#
# M
# 58
# BEND
# OR
# 2:10:38
#
#
#                     9 of 11
#
#
# M 55-59
#
#
#                     1 of 1
#
#
#
#
# 13
# 328
#
#
#                     BETH ANN ORTON
#
#
# F
# 41
# BEND
# OR
# 2:18:33
#
#
#                     3 of 6
#
#
# F 40-44
#
#
#                     1 of 2
#
#
#
#
# 14
# 339
#
#
#                     AURA SPANN
#
#
# F
# 38
# WILLIAMS
# OR
# 2:42:29
#
#
#                     4 of 6
#
#
# F 35-39
#
#
#                     2 of 2
#
#
#
#
# 15
# 306
#
#
#                     LISA GREEN
#
#
# F
# 42
# SNOQUALMIE PASS
# WA
# 2:46:26
#
#
#                     5 of 6
#
#
# F 40-44
#
#
#                     2 of 2
#
#
#
#
# 16
# 346
#
#
#                     STEFFEN WEEBER
#
#
# M
# 44
# PORTLAND
# OR
# 3:02:23
#
#
#                     10 of 11
#
#
# M 40-44
#
#
#                     2 of 2
#
#
#
#
# 17
# 318
#
#
#                     GREG LULOF
#
#
# M
# 46
# SEATTLE
# WA
# 3:05:25
#
#
#                     11 of 11
#
#
# M 45-49
#
#
#                     2 of 2
#
#
#
#
# 18
# 338
#
#
#                     OLIVIA SPADOLA
#
#
# F
# 27
# PORTLAND
# OR
# 3:27:28
#
#
#                     6 of 6
#
#
# F 25-29
#
#
#                     2 of 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Huber Timing
#
#
# Dark Mode

# %%
# Use the find_all() method of soup to extract useful html tags within a webpage.
soup.find_all('a')
# Out:
# [<a href="https://www.snowgoatskimo.com/" target="_blank">Snowgoat Skimo</a>,
#  <a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-info btn-sm" href="https://photos.google.com/share/AF1QipOH1NdRAy6eTU48sA9TjVQm8TtfJdINxX2YFsfvrM0NvHZYi76cLSTJO-A0H87fcQ?key=UnMzVnlKUG9BZF9rdk1zS21EVVI5dlU5VVBhNmdB" id="photo1Btn" role="button" target="_new"><i class="fas fa-camera"></i> Race Photos</a>,
#  <a href="https://www.teresadalsager.com/">Teresa Dalsager</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2023WyEaster" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Vertical - Open</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2023WyEasterVertHM" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Vertical - Heavy Mettle</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2023WyEasterLongHM" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Long - Heavy Mettle</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2023WyEasterLongSplitmo" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Long - Splitmo</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2023WyEasterShort" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Recreation - Open</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2023WyEasterLong" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2023WyEasterLong" href="#tabs-1" id="rootTab" style="font-size: 18px">Long - Open Results</a>,
#  <a href="https://www.hubertiming.com/"><img height="65" src="https://www.hubertiming.com//sites/all/themes/hubertiming/images/clockWithFinishSign_small.png" width="50"/>Huber Timing</a>,
#  <a href="https://facebook.com/hubertiming/"><img src="https://www.hubertiming.com/results/FB-f-Logo__blue_50.png"/></a>,
#  <a class="small" id="bestFeatureEver" style="color:#007bff">Dark Mode</a>]

# %%
# Use a for loop and the get("href") method to extract and print out only hyperlinks.
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# https://www.snowgoatskimo.com/
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# https://photos.google.com/share/AF1QipOH1NdRAy6eTU48sA9TjVQm8TtfJdINxX2YFsfvrM0NvHZYi76cLSTJO-A0H87fcQ?key=UnMzVnlKUG9BZF9rdk1zS21EVVI5dlU5VVBhNmdB
# https://www.teresadalsager.com/
# /results/2023WyEaster
# /results/2023WyEasterVertHM
# /results/2023WyEasterLongHM
# /results/2023WyEasterLongSplitmo
# /results/2023WyEasterShort
# /results/summary/2023WyEasterLong
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>Long - Open:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>18</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>11</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>6</td>
# </tr>, <tr>
# <td>Non-Binary:</td>
# <td>1</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>Age</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gender Place</th>
# <th>Age Group</th>
# <th>Age Group Place</th>
# </tr>, <tr data-bib="345">
# <td>1</td>
# <td>345</td>
# <td>
#
#                     ZACH VIOLETT
#
#                 </td>
# <td>M</td>
# <td>40</td>
# <td>BEND</td>
# <td>OR</td>
# <td>1:33:19</td>
# <td>
#
#                     1 of 11
#
#                 </td>
# <td>M 40-44</td>
# <td>
#
#                     1 of 2
#
#                 </td>
# </tr>, <tr data-bib="335">
# <td>2</td>
# <td>335</td>
# <td>
#
#                     KYLEE ROOD
#
#                 </td>
# <td>O</td>
# <td>34</td>
# <td>BEND</td>
# <td>OR</td>
# <td>1:42:56</td>
# <td>
#
#                     1 of 1
#
#                 </td>
# <td>O 30-34</td>
# <td>
#
#                     1 of 1
#
#                 </td>
# </tr>, <tr data-bib="323">
# <td>3</td>
# <td>323</td>
# <td>
#
#                     ZEBEDIAH MILLSLAGL
#
#                 </td>
# <td>M</td>
# <td>25</td>
# <td>BEND</td>
# <td>OR</td>
# <td>1:52:07</td>
# <td>
#
#                     2 of 11
#
#                 </td>
# <td>M 25-29</td>
# <td>
#
#                     1 of 2
#
#                 </td>
# </tr>, <tr data-bib="308">
# <td>4</td>
# <td>308</td>
# <td>
#
#                     DAVID GRIFFIN
#
#                 </td>
# <td>M</td>
# <td>35</td>
# <td>SEATTLE</td>
# <td>WA</td>
# <td>1:53:10</td>
# <td>
#
#                     3 of 11
#
#                 </td>
# <td>M 35-39</td>
# <td>
#
#                     1 of 2
#
#                 </td>
# </tr>]

# %%
# Getting all of the table’s rows in list form first and then convert that list into a pandas dataframe. 
# Below is a for loop that iterates through table rows and prints out the cells of the rows.
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>18</td>, <td>338</td>, <td>
#
#                     OLIVIA SPADOLA
#
#                 </td>, <td>F</td>, <td>27</td>, <td>PORTLAND</td>, <td>OR</td>, <td>3:27:28</td>, <td>
#
#                     6 of 6
#
#                 </td>, <td>F 25-29</td>, <td>
#
#                     2 of 2
#
#                 </td>]
# bs4.element.ResultSet

# %%
# To remove html tags using Beautiful Soup, pass the string of interest into BeautifulSoup() and use the get_text() method to extract the text without html tags.
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text(strip=True)
print(cleantext)
# Out:
# [18,338,OLIVIA SPADOLA,F,27,PORTLAND,OR,3:27:28,6 of 6,F 25-29,2 of 2]

# %%
# Below code generates an empty list, extracts text between html tags for each row, and appends it to the assigned list.
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    clean3 = BeautifulSoup(str_cells, "lxml").get_text(strip=True)
    list_rows.append(clean3)
print(clean2)
type(clean2)
# Out:
# [18, 338,
#
#                     OLIVIA SPADOLA
#
#                 , F, 27, PORTLAND, OR, 3:27:28,
#
#                     6 of 6
#
#                 , F 25-29,
#
#                     2 of 2
#
#                 ]
# str

# %%
# The next step is to convert the list into a pandas dataframe and view of the first 10 rows of data.
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                    [Finishers:,18]
# 2                                         [Male:,11]
# 3                                        [Female:,6]
# 4                                    [Non-Binary:,1]
# 5                                                 []
# 6  [1,345,ZACH VIOLETT,M,40,BEND,OR,1:33:19,1 of ...
# 7  [2,335,KYLEE ROOD,O,34,BEND,OR,1:42:56,1 of 1,...
# 8  [3,323,ZEBEDIAH MILLSLAGL,M,25,BEND,OR,1:52:07...
# 9  [4,308,DAVID GRIFFIN,M,35,SEATTLE,WA,1:53:10,3...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0     1                   2     3     4        5     6        7   \
# 0            []  None                None  None  None     None  None     None
# 1   [Finishers:   18]                None  None  None     None  None     None
# 2        [Male:   11]                None  None  None     None  None     None
# 3      [Female:    6]                None  None  None     None  None     None
# 4  [Non-Binary:    1]                None  None  None     None  None     None
# 5            []  None                None  None  None     None  None     None
# 6            [1   345        ZACH VIOLETT     M    40     BEND    OR  1:33:19
# 7            [2   335          KYLEE ROOD     O    34     BEND    OR  1:42:56
# 8            [3   323  ZEBEDIAH MILLSLAGL     M    25     BEND    OR  1:52:07
# 9            [4   308       DAVID GRIFFIN     M    35  SEATTLE    WA  1:53:10
#
#         8        9        10
# 0     None     None     None
# 1     None     None     None
# 2     None     None     None
# 3     None     None     None
# 4     None     None     None
# 5     None     None     None
# 6  1 of 11  M 40-44  1 of 2]
# 7   1 of 1  O 30-34  1 of 1]
# 8  2 of 11  M 25-29  1 of 2]
# 9  3 of 11  M 35-39  1 of 2]

# %%
# Use the strip() method to remove the opening square bracket on column "0".
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0     1                   2     3     4        5     6        7   \
# 0            ]  None                None  None  None     None  None     None
# 1   Finishers:   18]                None  None  None     None  None     None
# 2        Male:   11]                None  None  None     None  None     None
# 3      Female:    6]                None  None  None     None  None     None
# 4  Non-Binary:    1]                None  None  None     None  None     None
# 5            ]  None                None  None  None     None  None     None
# 6            1   345        ZACH VIOLETT     M    40     BEND    OR  1:33:19
# 7            2   335          KYLEE ROOD     O    34     BEND    OR  1:42:56
# 8            3   323  ZEBEDIAH MILLSLAGL     M    25     BEND    OR  1:52:07
# 9            4   308       DAVID GRIFFIN     M    35  SEATTLE    WA  1:53:10
#
#         8        9        10
# 0     None     None     None
# 1     None     None     None
# 2     None     None     None
# 3     None     None     None
# 4     None     None     None
# 5     None     None     None
# 6  1 of 11  M 40-44  1 of 2]
# 7   1 of 1  O 30-34  1 of 1]
# 8  2 of 11  M 25-29  1 of 2]
# 9  3 of 11  M 35-39  1 of 2]

# %%
# The table is missing table headers. So use find_all() method to get the table headers.
col_labels = soup.find_all('th')

# %%
# Similar to table rows, you can use Beautiful Soup to extract text in between html tags for table headers.
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, Age, City, State, Time, Gender Place, Age Group, Age Group Place]']

# %%
# Next convert the table headers to a new pandas dataframe.
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, Age, City, State, T...

# %%
# Again, split column "0" into multiple columns at the comma position for all rows.
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#        0     1      2        3     4      5       6      7              8   \
# 0  [Place   Bib   Name   Gender   Age   City   State   Time   Gender Place
#
#            9                  10
# 0   Age Group   Age Group Place]

# %%
# Next, concatenate the two dataframes into one using the concat() method.
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#             0     1                   2        3     4      5       6   \
# 0       [Place   Bib                Name   Gender   Age   City   State
# 0            ]  None                None     None  None   None    None
# 1   Finishers:   18]                None     None  None   None    None
# 2        Male:   11]                None     None  None   None    None
# 3      Female:    6]                None     None  None   None    None
# 4  Non-Binary:    1]                None     None  None   None    None
# 5            ]  None                None     None  None   None    None
# 6            1   345        ZACH VIOLETT        M    40   BEND      OR
# 7            2   335          KYLEE ROOD        O    34   BEND      OR
# 8            3   323  ZEBEDIAH MILLSLAGL        M    25   BEND      OR
#
#         7              8           9                  10
# 0     Time   Gender Place   Age Group   Age Group Place]
# 0     None           None        None               None
# 1     None           None        None               None
# 2     None           None        None               None
# 3     None           None        None               None
# 4     None           None        None               None
# 5     None           None        None               None
# 6  1:33:19        1 of 11     M 40-44            1 of 2]
# 7  1:42:56         1 of 1     O 30-34            1 of 1]
# 8  1:52:07        2 of 11     M 25-29            1 of 2]

# %%
# Next, re-configure the data frame so that the first row is the table header.
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place   Bib   Name   Gender   Age   City   State   Time  \
# 0      [Place   Bib   Name   Gender   Age   City   State   Time
# 0           ]  None   None     None  None   None    None   None
# 1  Finishers:   18]   None     None  None   None    None   None
# 2       Male:   11]   None     None  None   None    None   None
# 3     Female:    6]   None     None  None   None    None   None
#
#     Gender Place   Age Group   Age Group Place]
# 0   Gender Place   Age Group   Age Group Place]
# 0           None        None               None
# 1           None        None               None
# 2           None        None               None
# 3           None        None               None

# %%
# For analysis, getting an overview of the data as shown below.
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   [Place             25 non-null     object
#  1    Bib               23 non-null     object
#  2    Name              19 non-null     object
#  3    Gender            19 non-null     object
#  4    Age               19 non-null     object
#  5    City              19 non-null     object
#  6    State             19 non-null     object
#  7    Time              19 non-null     object
#  8    Gender Place      19 non-null     object
#  9    Age Group         19 non-null     object
#  10   Age Group Place]  19 non-null     object
# dtypes: object(11)
# memory usage: 2.3+ KB
# (25, 11)

# %%
# Transform it again to drop all rows with any missing values.
df6 = df5.dropna(axis=0, how='any')
df6.info()
df6.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   [Place             19 non-null     object
#  1    Bib               19 non-null     object
#  2    Name              19 non-null     object
#  3    Gender            19 non-null     object
#  4    Age               19 non-null     object
#  5    City              19 non-null     object
#  6    State             19 non-null     object
#  7    Time              19 non-null     object
#  8    Gender Place      19 non-null     object
#  9    Age Group         19 non-null     object
#  10   Age Group Place]  19 non-null     object
# dtypes: object(11)
# memory usage: 1.8+ KB
# (19, 11)

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#    [Place  Bib                Name  Gender  Age      City  State     Time  \
# 6       1  345        ZACH VIOLETT       M   40      BEND     OR  1:33:19
# 7       2  335          KYLEE ROOD       O   34      BEND     OR  1:42:56
# 8       3  323  ZEBEDIAH MILLSLAGL       M   25      BEND     OR  1:52:07
# 9       4  308       DAVID GRIFFIN       M   35   SEATTLE     WA  1:53:10
# 10      5  326         ADAM NILSEN       M   30  PORTLAND     OR  1:54:57
#
#     Gender Place  Age Group  Age Group Place]
# 6        1 of 11    M 40-44           1 of 2]
# 7         1 of 1    O 30-34           1 of 1]
# 8        2 of 11    M 25-29           1 of 2]
# 9        3 of 11    M 35-39           1 of 2]
# 10       4 of 11    M 30-34           1 of 2]

# %%
# Clean up the headers a bit more by renaming the '[Place' and ' Team]' columns.
# Make sure you include a space after the quotation mark in ' Team]'.
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Age Group Place]': 'Age Group Place'},inplace=True)
df7.head()
# Out:
#    Place  Bib                Name  Gender  Age      City  State     Time  \
# 6      1  345        ZACH VIOLETT       M   40      BEND     OR  1:33:19
# 7      2  335          KYLEE ROOD       O   34      BEND     OR  1:42:56
# 8      3  323  ZEBEDIAH MILLSLAGL       M   25      BEND     OR  1:52:07
# 9      4  308       DAVID GRIFFIN       M   35   SEATTLE     WA  1:53:10
# 10     5  326         ADAM NILSEN       M   30  PORTLAND     OR  1:54:57
#
#     Gender Place  Age Group Age Group Place
# 6        1 of 11    M 40-44         1 of 2]
# 7         1 of 1    O 30-34         1 of 1]
# 8        2 of 11    M 25-29         1 of 2]
# 9        3 of 11    M 35-39         1 of 2]
# 10       4 of 11    M 30-34         1 of 2]

# %%
# Data cleaning step involves removing the closing bracket for cells in the "Team" column.
df7['Age Group Place'] = df7['Age Group Place'].str.strip(']')
df7
# Out:
#    Place  Bib                Name  Gender  Age             City  State  \
# 6      1  345        ZACH VIOLETT       M   40             BEND     OR
# 7      2  335          KYLEE ROOD       O   34             BEND     OR
# 8      3  323  ZEBEDIAH MILLSLAGL       M   25             BEND     OR
# 9      4  308       DAVID GRIFFIN       M   35          SEATTLE     WA
# 10     5  326         ADAM NILSEN       M   30         PORTLAND     OR
# 11     6  293       KAITLIN ALLEN       F   36             BEND     OR
# 12     7  362       GEORGE REYNYA       M   47          REDMOND     WA
# 13     8  305          ELY GERBIN       M   33         ISSAQUAH     WA
# 14     9  509      JOHN AMMONDSON       M   29         PORTLAND     OR
# 15    10  307         TYLER GREEN       M   39         PORTLAND     OR
# 16    11  297     MICHELLE BUNCKE       F   27         PORTLAND     OR
# 17    12  329         DAN PACKMAN       M   58             BEND     OR
# 18    13  328      BETH ANN ORTON       F   41             BEND     OR
# 19    14  339          AURA SPANN       F   38         WILLIAMS     OR
# 20    15  306          LISA GREEN       F   42  SNOQUALMIE PASS     WA
# 21    16  346      STEFFEN WEEBER       M   44         PORTLAND     OR
# 22    17  318          GREG LULOF       M   46          SEATTLE     WA
# 23    18  338      OLIVIA SPADOLA       F   27         PORTLAND     OR
#
#        Time  Gender Place  Age Group Age Group Place
# 6   1:33:19       1 of 11    M 40-44          1 of 2
# 7   1:42:56        1 of 1    O 30-34          1 of 1
# 8   1:52:07       2 of 11    M 25-29          1 of 2
# 9   1:53:10       3 of 11    M 35-39          1 of 2
# 10  1:54:57       4 of 11    M 30-34          1 of 2
# 11  1:56:01        1 of 6    F 35-39          1 of 2
# 12  2:05:40       5 of 11    M 45-49          1 of 2
# 13  2:07:17       6 of 11    M 30-34          2 of 2
# 14  2:08:22       7 of 11    M 25-29          2 of 2
# 15  2:09:02       8 of 11    M 35-39          2 of 2
# 16  2:10:01        2 of 6    F 25-29          1 of 2
# 17  2:10:38       9 of 11    M 55-59          1 of 1
# 18  2:18:33        3 of 6    F 40-44          1 of 2
# 19  2:42:29        4 of 6    F 35-39          2 of 2
# 20  2:46:26        5 of 6    F 40-44          2 of 2
# 21  3:02:23      10 of 11    M 40-44          2 of 2
# 22  3:05:25      11 of 11    M 45-49          2 of 2
# 23  3:27:28        6 of 6    F 25-29          2 of 2

# %%
print(df7.columns)
# Out:
# Index(['Place', ' Bib', ' Name', ' Gender', ' Age', ' City', ' State', ' Time',
#        ' Gender Place', ' Age Group', 'Age Group Place'],
#       dtype='object')

# %%
# Convert the column to a list first for manipulation.
time_list = df7[' Time'].tolist()

# %%
# Use a for loop to convert ' Time' to minutes

time_mins = []
for i in time_list:
    time_parts = i.split(':')
    if len(time_parts) == 3:
        h, m, s = time_parts
        math = (int(h) * 3600 + int(m) * 60 + int(s))/60
        time_mins.append(math)
    elif len(time_parts) == 2:
        m, s = time_parts
        math = (int(m) * 60 + int(s))/60
        time_mins.append(math)

# %%
# Convert the list back into a dataframe and create a new column ("Runner_mins") for runner times expressed in just minutes. 
df7['Runner_mins'] = time_mins
df7.head()
# Out:
#    Place  Bib                Name  Gender  Age      City  State     Time  \
# 6      1  345        ZACH VIOLETT       M   40      BEND     OR  1:33:19
# 7      2  335          KYLEE ROOD       O   34      BEND     OR  1:42:56
# 8      3  323  ZEBEDIAH MILLSLAGL       M   25      BEND     OR  1:52:07
# 9      4  308       DAVID GRIFFIN       M   35   SEATTLE     WA  1:53:10
# 10     5  326         ADAM NILSEN       M   30  PORTLAND     OR  1:54:57
#
#     Gender Place  Age Group Age Group Place  Runner_mins
# 6        1 of 11    M 40-44          1 of 2    93.316667
# 7         1 of 1    O 30-34          1 of 1   102.933333
# 8        2 of 11    M 25-29          1 of 2   112.116667
# 9        3 of 11    M 35-39          1 of 2   113.166667
# 10       4 of 11    M 30-34          1 of 2   114.950000

# %%
# "describe" method that computes a generous list of explanatory statistics for the dataframe.
df7.describe(include=[np.number])
# Out:
#        Runner_mins
# count    18.000000
# mean    137.012963
# std      31.173269
# min      93.316667
# 25%     115.216667
# 50%     128.700000
# 75%     156.500000
# max     207.466667

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5


df7.boxplot(column='Runner_mins')
plt.grid(True, axis='y')
plt.ylabel('Time')
plt.xticks([1], ['Runners'])
# Out:
# ([<matplotlib.axis.XTick at 0x18a9d53fd10>], [Text(1, 0, 'Runners')])

# %%
x = df7['Runner_mins']
ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12756\2333182940.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
f_fuko = df7.loc[df7[' Gender']=='F']['Runner_mins']
m_fuko = df7.loc[df7[' Gender']=='M']['Runner_mins']
sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12756\3586507676.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\AppData\Local\Temp\ipykernel_12756\3586507676.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g_stats = df7.groupby(" Gender", as_index=True).describe()
print(g_stats)
# Out:
#         Runner_mins                                                 \
#               count        mean        std         min         25%
#  Gender
# F               6.0  153.494444  32.681316  116.016667  132.150000
# M              11.0  131.121212  28.296109   93.316667  114.058333
# O               1.0  102.933333        NaN  102.933333  102.933333
#
#
#                 50%         75%         max
#  Gender
# F        150.516667  165.445833  207.466667
# M        127.283333  129.833333  185.416667
# O        102.933333  102.933333  102.933333

# %%
df7.boxplot(column='Runner_mins', by=' Gender')
plt.ylabel('Time')
plt.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
Does your code succeed with this data as well? How do the results compare with the older, 2017 race?
Answer:
Yes.There are significant differences between the two races in terms of average finish times, standard finish times and range of finish times.
The 2023 race appears to have longer average finish times, higher variability, and a wider range of finish times compared to the 2017 race.
